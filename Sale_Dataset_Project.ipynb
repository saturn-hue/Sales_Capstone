# %%
# Importing Dependancies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from datetime import datetime

# %%
# Loading/Reading csv Dataset into Dataframe
df = pd.read_csv(r"C:\Users\Home\Desktop\10 Alytics  Data Engineering\Sales_Dataset_Capstone_Project_Nov_2025\Sales Dataset.csv")
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
df.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'PaymentMode', 'Order Date', 'CustomerName', 'State', 'City',
#        'Year-Month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1194 non-null   object
#  1   Amount        1194 non-null   int64
#  2   Profit        1194 non-null   int64
#  3   Quantity      1194 non-null   int64
#  4   Category      1194 non-null   object
#  5   Sub-Category  1194 non-null   object
#  6   PaymentMode   1194 non-null   object
#  7   Order Date    1194 non-null   object
#  8   CustomerName  1194 non-null   object
#  9   State         1194 non-null   object
#  10  City          1194 non-null   object
#  11  Year-Month    1194 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 112.1+ KB

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()                
              .str.replace(' ', '_',  regex=True)
)
df.head()
# Out:
#   order_id  amount  profit  quantity     category      sub-category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   paymentmode  order_date   customername     state     city year-month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
df.columns
# Out:
# Index(['order_id', 'amount', 'profit', 'quantity', 'category', 'sub-category',
#        'paymentmode', 'order_date', 'customername', 'state', 'city',
#        'year-month'],
#       dtype='object')

# %%
# Convert to lowercase and replace spaces/dashes with underscore
df.columns = ['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
           'PaymentMode', 'Order Date', 'CustomerName', 'State', 'City', 'Year-Month']

df.columns  = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

df.columns
# Out:
# Index(['order_id', 'amount', 'profit', 'quantity', 'category', 'sub_category',
#        'paymentmode', 'order_date', 'customername', 'state', 'city',
#        'year_month'],
#       dtype='object')

# %%
#categories  table
category_df = df[['category', 'sub_category']].drop_duplicates().reset_index(drop=True)
category_df['category_id'] = category_df.index + 1
category_df = category_df[['category_id', 'category', 'sub_category']]


#category_df = df[['category']].reset_index(drop=True)
#category_df['category_id'] = category_df.index + 1
#category_df =  category_df[['category','sub_category']]

# %%
category_df
# Out:
#     category_id         category      sub_category
# 0             1      Electronics  Electronic Games
# 1             2      Electronics          Printers
# 2             3  Office Supplies              Pens
# 3             4      Electronics           Laptops
# 4             5        Furniture            Tables
# 5             6        Furniture            Chairs
# 6             7  Office Supplies           Markers
# 7             8        Furniture             Sofas
# 8             9  Office Supplies             Paper
# 9            10  Office Supplies           Binders
# 10           11      Electronics            Phones
# 11           12        Furniture         Bookcases

# %%
# customers table

#customer_df = df[['customername']].reset_index(drop=True)
#customer_df['customer_id'] = customer_df.index + 1
#customer_df = customer_df[['customer_id', 'customername', 'state', 'city']]

customer_df = df[['customername', 'state', 'city']].drop_duplicates().reset_index(drop=True)
customer_df['customer_id'] = customer_df.index + 1
customer_df = customer_df[['customer_id', 'customername', 'state', 'city']]

# %%
customer_df
# Out:
#      customer_id        customername     state           city
# 0              1       David Padilla   Florida          Miami
# 1              2       Connor Morgan  Illinois        Chicago
# 2              3        Robert Stone  New York        Buffalo
# 3              4         John Fields   Florida        Orlando
# 4              5       Clayton Smith   Florida          Miami
# ..           ...                 ...       ...            ...
# 802          803        Megan Mclean  New York  New York City
# 803          804        Caitlin Hunt  New York      Rochester
# 804          805       Jenna Holland     Texas         Austin
# 805          806  Stephanie Oconnell  New York        Buffalo
# 806          807         Andrea Hill  Illinois        Chicago
#
# [807 rows x 4 columns]

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   807 non-null    int64
#  1   customername  807 non-null    object
#  2   state         807 non-null    object
#  3   city          807 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 25.3+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'amount', 'profit', 'quantity', 'category', 'sub_category',
#        'paymentmode', 'order_date', 'customername', 'state', 'city',
#        'year_month'],
#       dtype='object')

# %%
# order table
order_df = df[['order_id', 'amount', 'profit', 'quantity', 'paymentmode', 'order_date', 'year_month']].drop_duplicates().reset_index(drop=True)
order_df['order_id'] = order_df.index + 1
order_df = order_df[['order_id', 'amount', 'profit', 'quantity', 'paymentmode', 'order_date', 'year_month']]

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     1194 non-null   int64
#  1   amount       1194 non-null   int64
#  2   profit       1194 non-null   int64
#  3   quantity     1194 non-null   int64
#  4   paymentmode  1194 non-null   object
#  5   order_date   1194 non-null   object
#  6   year_month   1194 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 65.4+ KB

# %%
order_df
# Out:
#       order_id  amount  profit  quantity paymentmode  order_date year_month
# 0            1    9726    1275         5         UPI  2023-06-27    2023-06
# 1            2    9726    1275         5         UPI  2024-12-27    2024-12
# 2            3    9726    1275         5         UPI  2021-07-25    2021-07
# 3            4    4975    1330        14         UPI  2023-06-27    2023-06
# 4            5    4975    1330        14         UPI  2024-12-27    2024-12
# ...        ...     ...     ...       ...         ...         ...        ...
# 1189      1190    8825    3594        15  Debit Card  2024-07-31    2024-07
# 1190      1191    2082     642         8         EMI  2020-06-02    2020-06
# 1191      1192    2082     642         8         EMI  2022-12-15    2022-12
# 1192      1193    2082     642         8         EMI  2020-08-07    2020-08
# 1193      1194     914     163        13         UPI  2024-10-26    2024-10
#
# [1194 rows x 7 columns]

# %%
import os
! pip install psycopg2

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### database setup

# %%
import os
password = os.environ.get("Emuejevoke@@@3")

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    user="postgres",
    password="Emuejevoke@@@3",
    dbname="sales_dataset_capstone_project"
)

# %% [markdown]
# ### Connecting to PostgreSQL

# %%
connection_string = "postgresql://postgres:Emuejevoke%40%40%403@localhost:5432/sales_dataset_capstone_project"
engine = create_engine("postgresql+psycopg2://postgres:Emuejevoke%40%40%403@localhost:5432/sales_dataset_capstone_project")

# %% [markdown]
# ### Testing Connection to PgAdmin(postgresql)

# %%
connection = engine.connect()
print("Connection successful!")
connection.close()
# Out:
# Connection successful!

# %%
df.describe()
# Out:
#             amount       profit     quantity
# count  1194.000000  1194.000000  1194.000000
# mean   5178.089615  1348.992462    10.674204
# std    2804.921955  1117.992573     5.777102
# min     508.000000    50.000000     1.000000
# 25%    2799.000000   410.000000     6.000000
# 50%    5152.000000  1014.000000    11.000000
# 75%    7626.000000  2035.000000    16.000000
# max    9992.000000  4930.000000    20.000000

# %%
# category_df = pd.DataFrame({'year_month': ['2023-11', '2024-01', '2025-07']})
# category_df['year_month'] = pd.to_datetime(df['year_month'], format='%Y-%m')
# category_df

# %%
df.head()
# Out:
#   order_id  amount  profit  quantity     category      sub_category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   paymentmode  order_date   customername     state     city year_month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
df['date'] = pd.to_datetime(df['category'])
df['year_month'] = df['date'].dt.to_period('M')
monthly_avg = df.groupby('year_month')['category'].mean().reset_index()
monthly_avg.columns = ['year_month', 'avg_sales']
print(monthly_avg)
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_33900\1961913923.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['category'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[483], line 1
# ----> 1 df['date'] = pd.to_datetime(df['category'])
#       2 df['year_month'] = df['date'].dt.to_period('M')
#       3 monthly_avg = df.groupby('year_month')['category'].mean().reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# ...

# %%
print(df.columns)
# Out:
# Index(['order_id', 'amount', 'profit', 'quantity', 'category', 'sub_category',
#        'paymentmode', 'order_date', 'customername', 'state', 'city',
#        'year_month'],
#       dtype='object')

# %%
df.tail()
# Out:
#      order_id  amount  profit  quantity         category sub_category  \
# 1189  B-26370    8825    3594        15        Furniture       Tables
# 1190  B-26298    2082     642         8      Electronics       Phones
# 1191  B-26298    2082     642         8      Electronics       Phones
# 1192  B-26298    2082     642         8      Electronics       Phones
# 1193  B-25068     914     163        13  Office Supplies      Markers
#
#      paymentmode  order_date        customername     state           city  \
# 1189  Debit Card  2024-07-31        Megan Mclean  New York  New York City
# 1190         EMI  2020-06-02        Caitlin Hunt  New York      Rochester
# 1191         EMI  2022-12-15       Jenna Holland     Texas         Austin
# 1192         EMI  2020-08-07  Stephanie Oconnell  New York        Buffalo
# 1193         UPI  2024-10-26         Andrea Hill  Illinois        Chicago
#
#      year_month
# 1189    2024-07
# 1190    2020-06
# 1191    2022-12
# 1192    2020-08
# ...

# %%
# Checking the shape of the DataFrame
df.shape
# Out:
# (1194, 12)

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# order_id        0
# amount          0
# profit          0
# quantity        0
# category        0
# sub_category    0
# paymentmode     0
# order_date      0
# customername    0
# state           0
# city            0
# year_month      0
# dtype: int64

# %%
df.dtypes
# Out:
# order_id        object
# amount           int64
# profit           int64
# quantity         int64
# category        object
# sub_category    object
# paymentmode     object
# order_date      object
# customername    object
# state           object
# city            object
# year_month      object
# dtype: object

# %%
df.duplicated(subset=["category"]).mean()
# Out:
# 0.9974874371859297

# %%
df.drop_duplicates()
# Out:
#      order_id  amount  profit  quantity         category      sub_category  \
# 0     B-26776    9726    1275         5      Electronics  Electronic Games
# 1     B-26776    9726    1275         5      Electronics  Electronic Games
# 2     B-26776    9726    1275         5      Electronics  Electronic Games
# 3     B-26776    4975    1330        14      Electronics          Printers
# 4     B-26776    4975    1330        14      Electronics          Printers
# ...       ...     ...     ...       ...              ...               ...
# 1189  B-26370    8825    3594        15        Furniture            Tables
# 1190  B-26298    2082     642         8      Electronics            Phones
# 1191  B-26298    2082     642         8      Electronics            Phones
# 1192  B-26298    2082     642         8      Electronics            Phones
# 1193  B-25068     914     163        13  Office Supplies           Markers
#
# ...

# %%
category_df.shape
# Out:
# (12, 3)

# %%
category_df.head()
# Out:
#    category_id         category      sub_category
# 0            1      Electronics  Electronic Games
# 1            2      Electronics          Printers
# 2            3  Office Supplies              Pens
# 3            4      Electronics           Laptops
# 4            5        Furniture            Tables

# %%
category_df
# Out:
#     category_id         category      sub_category
# 0             1      Electronics  Electronic Games
# 1             2      Electronics          Printers
# 2             3  Office Supplies              Pens
# 3             4      Electronics           Laptops
# 4             5        Furniture            Tables
# 5             6        Furniture            Chairs
# 6             7  Office Supplies           Markers
# 7             8        Furniture             Sofas
# 8             9  Office Supplies             Paper
# 9            10  Office Supplies           Binders
# 10           11      Electronics            Phones
# 11           12        Furniture         Bookcases

# %%
customer_df
# Out:
#      customer_id        customername     state           city
# 0              1       David Padilla   Florida          Miami
# 1              2       Connor Morgan  Illinois        Chicago
# 2              3        Robert Stone  New York        Buffalo
# 3              4         John Fields   Florida        Orlando
# 4              5       Clayton Smith   Florida          Miami
# ..           ...                 ...       ...            ...
# 802          803        Megan Mclean  New York  New York City
# 803          804        Caitlin Hunt  New York      Rochester
# 804          805       Jenna Holland     Texas         Austin
# 805          806  Stephanie Oconnell  New York        Buffalo
# 806          807         Andrea Hill  Illinois        Chicago
#
# [807 rows x 4 columns]

# %%
order_df
# Out:
#       order_id  amount  profit  quantity paymentmode  order_date year_month
# 0            1    9726    1275         5         UPI  2023-06-27    2023-06
# 1            2    9726    1275         5         UPI  2024-12-27    2024-12
# 2            3    9726    1275         5         UPI  2021-07-25    2021-07
# 3            4    4975    1330        14         UPI  2023-06-27    2023-06
# 4            5    4975    1330        14         UPI  2024-12-27    2024-12
# ...        ...     ...     ...       ...         ...         ...        ...
# 1189      1190    8825    3594        15  Debit Card  2024-07-31    2024-07
# 1190      1191    2082     642         8         EMI  2020-06-02    2020-06
# 1191      1192    2082     642         8         EMI  2022-12-15    2022-12
# 1192      1193    2082     642         8         EMI  2020-08-07    2020-08
# 1193      1194     914     163        13         UPI  2024-10-26    2024-10
#
# [1194 rows x 7 columns]

# %%
df
# Out:
#      order_id  amount  profit  quantity         category      sub_category  \
# 0     B-26776    9726    1275         5      Electronics  Electronic Games
# 1     B-26776    9726    1275         5      Electronics  Electronic Games
# 2     B-26776    9726    1275         5      Electronics  Electronic Games
# 3     B-26776    4975    1330        14      Electronics          Printers
# 4     B-26776    4975    1330        14      Electronics          Printers
# ...       ...     ...     ...       ...              ...               ...
# 1189  B-26370    8825    3594        15        Furniture            Tables
# 1190  B-26298    2082     642         8      Electronics            Phones
# 1191  B-26298    2082     642         8      Electronics            Phones
# 1192  B-26298    2082     642         8      Electronics            Phones
# 1193  B-25068     914     163        13  Office Supplies           Markers
#
# ...

# %%
# deducting Total amount from Total profit
column_range = df["amount"].sum() - df["profit"].sum()
column_range
# Out:
# 4571942

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      1194 non-null   object
#  1   amount        1194 non-null   int64
#  2   profit        1194 non-null   int64
#  3   quantity      1194 non-null   int64
#  4   category      1194 non-null   object
#  5   sub_category  1194 non-null   object
#  6   paymentmode   1194 non-null   object
#  7   order_date    1194 non-null   object
#  8   customername  1194 non-null   object
#  9   state         1194 non-null   object
#  10  city          1194 non-null   object
#  11  year_month    1194 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 112.1+ KB

# %%
df.category.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1194 entries, 0 to 1193
# Series name: category
# Non-Null Count  Dtype
# --------------  -----
# 1194 non-null   object
# dtypes: object(1)
# memory usage: 9.5+ KB

# %%
df['category']
# Out:
# 0           Electronics
# 1           Electronics
# 2           Electronics
# 3           Electronics
# 4           Electronics
#              ...
# 1189          Furniture
# 1190        Electronics
# 1191        Electronics
# 1192        Electronics
# 1193    Office Supplies
# Name: category, Length: 1194, dtype: object

# %%
# To list items in category column
# df['category'].tolist()

# %%
# Count of frequency of items in category 
df['category'].value_counts()
# Out:
# category
# Furniture          407
# Office Supplies    399
# Electronics        388
# Name: count, dtype: int64

# %%
# Calculating category maximum
df['category'].value_counts().max()
# Out:
# 407

# %%
# Calculating category mean
df['category'].value_counts().mean()
# Out:
# 398.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      1194 non-null   object
#  1   amount        1194 non-null   int64
#  2   profit        1194 non-null   int64
#  3   quantity      1194 non-null   int64
#  4   category      1194 non-null   object
#  5   sub_category  1194 non-null   object
#  6   paymentmode   1194 non-null   object
#  7   order_date    1194 non-null   object
#  8   customername  1194 non-null   object
#  9   state         1194 non-null   object
#  10  city          1194 non-null   object
#  11  year_month    1194 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 112.1+ KB

# %% [markdown]
# ### Order sorted from the most to least frequent

# %%
#  Order  sorted from the most to least frequent
frequency_counts = df.value_counts()
frequency_counts
# Out:
# order_id  amount  profit  quantity  category         sub_category      paymentmode  order_date  customername       state       city           year_month
# B-25004   9965    3033    16        Office Supplies  Markers           COD          2020-06-17  Jennifer Marshall  California  San Francisco  2020-06       1
# B-26324   6355    1335    15        Electronics      Electronic Games  Debit Card   2021-06-06  Keith Reese        Texas       Austin         2021-06       1
# B-26321   2062    848     6         Office Supplies  Markers           Credit Card  2024-03-04  Christine Wheeler  Florida     Tampa          2024-03       1
# B-26319   7748    1706    16        Electronics      Electronic Games  EMI          2020-05-02  Andrew Fernandez   Ohio        Cincinnati     2020-05       1
#           6381    2763    20        Office Supplies  Markers           UPI          2020-05-02  Andrew Fernandez   Ohio        Cincinnati     2020-05       1
# ...

# %%
df['category']
# Out:
# 0           Electronics
# 1           Electronics
# 2           Electronics
# 3           Electronics
# 4           Electronics
#              ...
# 1189          Furniture
# 1190        Electronics
# 1191        Electronics
# 1192        Electronics
# 1193    Office Supplies
# Name: category, Length: 1194, dtype: object

# %%
# Calculating category mean
avg = df['order_df'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_df'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[524], line 2
#       1 # Calculating category mean
# ----> 2 avg = df['order_df'].mean()
#
# ...

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     1194 non-null   int64
#  1   amount       1194 non-null   int64
#  2   profit       1194 non-null   int64
#  3   quantity     1194 non-null   int64
#  4   paymentmode  1194 non-null   object
#  5   order_date   1194 non-null   object
#  6   year_month   1194 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 65.4+ KB

# %%
df.head()
# Out:
#   order_id  amount  profit  quantity     category      sub_category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   paymentmode  order_date   customername     state     city year_month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
# Calculating category mean
df['category'].value_counts().median()
# Out:
# 399.0

# %%
df['state'].describe()
# Out:
# count         1194
# unique           6
# top       New York
# freq           226
# Name: state, dtype: object

# %%
  #  State with Minimum
df['state'].min()
# Out:
# 'California'

# %%
 # Number of unique values
df['state'].nunique()
# Out:
# 6

# %%
# Top customer
df['customername'].describe()
# Out:
# count                  1194
# unique                  802
# top       Michael Rodriguez
# freq                      4
# Name: customername, dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'amount', 'profit', 'quantity', 'category', 'sub_category',
#        'paymentmode', 'order_date', 'customername', 'state', 'city',
#        'year_month'],
#       dtype='object')

# %%
# Customer aggregate Minimum
df['customername'].agg(['min'])
# Out:
# min    Aaron Dunn
# Name: customername, dtype: object

# %%
# City aggregate Minimum
df['city'].agg(['min'])
# Out:
# min    Austin
# Name: city, dtype: object
